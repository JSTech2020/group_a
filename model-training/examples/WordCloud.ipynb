# %% [markdown]
# <p class="h4 alert alert-danger">
#     Please make sure that the pretrained model exists in the path "./models"
# </p>

# %% [markdown]
# <p class="alert alert-danger">
# Also make sure that the BERT server is running and has access to the pretrained model. We can run the BERT server by writing the following command in the command-line:
# </p>
# <code>> cd [ repo_dir ]/model_training/models</code>
# <br />
# <code>> bert-serving-start -model_dir ./multi_cased_L-12_H-768_A-12/ -num_worker=1 -show_tokens_to_client</code>

# %%
# import required libraries
import pandas as pd
import numpy as np
from pymongo import MongoClient
import bert_serving.client as bert
from sklearn.cluster import KMeans
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfTransformer

# %%
"""
Database loading
"""
# define params for db operations 
uri = 'mongodb://localhost:27017/'
database = 'zs_database'
collection_fetch = 'autotags'
collection_push = 'labels'

# initiate variables
df = pd.DataFrame()
db = object

# connect to db. TODO: Handle exception cases
client = MongoClient(uri)
db = client[database]

# retrieving required data
df = pd.DataFrame(list(db[collection_fetch].find({}, {"_id":0, "lemmas": 1, "story_id": 1, "tokens": 1, "pos": 1, "nouns":1, "entities":1})))

df
# Out:
#      story_id                                             tokens  \
# 0          19  [Radio, ÜberAll, sendet, mal, ZukunftsmusikAm,...
# 1          21  [Dorf, pflanzt, SauerstoffMathilda, schaute, m...
# 2          24  [langer, lebte, Witwer, einzigen, Tochter, Mut...
# 3          25  [Beste, Partys, Buffet, findet, Bernd, steht, ...
# 4          27  [Endlose, Laubwälder, saftige, Weiden, Wildblu...
# ..        ...                                                ...
# 195       489  [Familie, Maus, verläßt, altes, HausErster, Su...
# 196       490  [WolkenlandGlück, einst, Merkmal, Wolkenlandes...
# 197       491  [Tages, wacht, Miro, findet, komplett, Welt, s...
# 198       492  [Goldene, Sonnenstrahlen, fielen, klare, Wasse...
# 199       494  [Mutter, ErdeIn, verschlafenen, Dorf, namens, ...
#
#                                                 lemmas  \
# 0    [Radio, ÜberAll, senden, mal, ZukunftsmusikAm,...
# 1    [Dorf, pflanzen, SauerstoffMathilda, schauen, ...
# 2    [lang, leben, Witwer, einzig, Tochter, Mutter,...
# 3    [Beste, Party, Buffet, finden, Bernd, stehen, ...
# 4    [Endlose, Laubwälder, saftig, Weide, Wildblume...
# ..                                                 ...
# 195  [Familie, Maus, verlassen, alt, HausErster, Su...
# 196  [WolkenlandGlück, einen, Merkmal, Wolkenlandes...
# 197  [Tag, wachen, Miro, finden, komplett, Welt, sc...
# 198  [Goldene, Sonnenstrahlen, fallen, klaren, Wass...
# 199  [Mutter, ErdeIn, verschlafen, Dorf, namens, Na...
#
#                                                    pos  \
# 0    [NOUN, PROPN, VERB, ADV, PROPN, PROPN, PROPN, ...
# 1    [NOUN, VERB, PROPN, VERB, ADJ, NOUN, PROPN, AD...
# 2    [ADJ, VERB, NOUN, ADJ, NOUN, NOUN, NOUN, VERB,...
# 3    [NOUN, PROPN, NOUN, VERB, PROPN, VERB, NOUN, N...
# 4    [ADJ, NOUN, ADJ, ADJ, NOUN, ADJ, NOUN, VERB, A...
# ..                                                 ...
# 195  [NOUN, PROPN, VERB, ADJ, NOUN, NOUN, PROPN, NO...
# 196  [NOUN, ADV, NOUN, NOUN, NOUN, ADJ, NOUN, VERB,...
# 197  [NOUN, VERB, PROPN, VERB, ADJ, NOUN, ADJ, VERB...
# 198  [ADJ, NOUN, VERB, ADJ, NOUN, VERB, ADJ, NOUN, ...
# 199  [NOUN, PROPN, ADJ, NOUN, ADP, PROPN, VERB, NOU...
#
#                                                  nouns  \
# 0    [Radio ÜberAll, ZukunftsmusikAm Mikrofon Krump...
# 1    [Unser Dorf, SauerstoffMathilda, dem Fenster G...
# 2    [Es, ein Witwer, seiner einzigen Tochter, Die ...
# 3    [Das Beste, Partys, das Buffet, Bernd Ihm, der...
# 4    [Endlose Laubwälder, Wildblumenwiesen, wunders...
# ..                                                 ...
# 195  [Familie Maus, ihr gutes altes HausErster Teil...
# 196  [Das WolkenlandGlück, ein Merkmal, des Wolkenl...
# 197  [Eines Tages, Miro, eine komplett neue Welt, s...
# 198  [Goldene Sonnenstrahlen, die klare Wasseroberf...
# 199  [                                             ...
#
#                                               entities
# 0    [[Radio ÜberAll, MISC], [ZukunftsmusikAm Mikro...
# 1    [[SauerstoffMathilda, MISC], [Das Thermometer ...
# 2    [[Die Mutter des Mädchens, MISC], [warAlles, M...
# 3    [[Bernd Ihm, PER], [Lea, PER], [Papa, LOC], [W...
# 4    [[Endlose Laubwälder, PER], [Transsilvanien, L...
# ..                                                 ...
# 195  [[Familie Maus, PER], [HausErster, MISC], [Die...
# 196  [[WolkenlandGlück, MISC], [Wolkenlandes Doch S...
# 197  [[Miro, LOC], [Miro, LOC], [Zeit vor dem Umwel...
# 198  [[Goldene Sonnenstrahlen, MISC], [Rhonda, LOC]...
# 199  [[Natura, PER], [Erde, LOC], [Ben, PER], [Laur...
#
# [200 rows x 6 columns]

# %%
"""
Function: Using TF-IDF to extract key words in different Corpus.
"""

# input: list of string
# output: list of list of keywords 
def keyword(corpus, topK):
    
    key_list = []
    
    # Word frequency matrix 
    vectorizer = CountVectorizer()
    X = vectorizer.fit_transform(corpus) 
    
    # list of all words in Bag-of-Words model
    word = vectorizer.get_feature_names() 
    
    # TF-IDF Matrix
    transformer = TfidfTransformer()
    tfidf = transformer.fit_transform(X)
    
    # weight[i][j] represents the weight of word j in text i
    weight = tfidf.toarray()
    
    for i in range(len(weight)):
        keys=[]
        zipped = zip(word,weight[i])
        sorted_l=sorted(zipped,key=lambda t:t[1],reverse=True)
        
        for n in range(topK):
            keys.append(sorted_l[n][0])
            
        key_list.append(keys)
    
    return key_list

# %%
"""
Term_Frequency—Count
"""
word_count = {}
for story in df['lemmas'].values.tolist():
    for token in story:
        if token.lower() in word_count:
            word_count[token.lower()] +=1
        else:
            word_count[token.lower()] =1
            
word_freq = []
for word,freq in word_count.items():
    word_freq.append((word,freq))
 
 
#sorted
word_freq.sort(key = lambda x:x[1],reverse = True)
num=len(word_freq)

# generate the most and least frequent words
most_freq=[]
least_freq=[]
for i in range(300):
    most_freq.append(word_freq[i][0])
    least_freq.append(word_freq[num-1-i][0])

    
print(most_freq)
# Out:
# ['sehen', 'fragen', 'mal', 'stehen', 'mensch', 'finden', 'auge', 'hören', 'einfach', 'hand', 'baum', 'schauen', 'erde', 'denken', 'mutter', 'vater', 'rufen', 'haus', 'tier', 'leben', 'weg', 'kind', 'frau', 'eltern', 'kopf', 'mein', 'lassen', 'weiß', 'alt', 'wasser', 'welt', 'wald', 'halten', 'mama', 'schule', 'helfen', 'fahren', 'ziehen', 'laufen', 'erzählen', 'wissen', 'nächst', 'paar', 'liegen', 'nehmen', 'freund', 'papa', 'genau', 'bleiben', 'brauchen', 'setzen', 'glauben', 'luft', 'erklären', 'blick', 'essen', 'kommen', 'schnellen', 'sitzen', 'stellen', 'bringen', 'laut', 'schön', 'idee', 'sagen', 'sogar', 'zeigen', 'eigentlich', 'beginnen', 'bekommen', 'legen', 'boden', 'junge', 'verstehen', 'meinen', 'antworten', 'plötzlich', 'mann', 'lächeln', 'versuchen', 'scheinen', 'mädchen', 'fallen', 'meer', 'gesicht', 'fast', 'stimme', 'auto', 'langsam', 'nicken', 'müll', 'lisa', 'sprechen', 'drehen', 'geben', 'klimawandel', 'lachen', 'letzt', 'moment', 'fest', 'gehen', 'wusste', 'voll', 'blicken', 'sonnen', 'pflanze', 'schließlich', 'fühlen', 'leute', 'passieren', 'kennen', 'oma', 'machen', 'sichern', 'arm', 'gedanke', 'tim', 'wort', 'bevor', 'garten', 'tür', 'klima', 'sofort', 'herr', 'woche', 'werfen', 'seite', 'stadt', 'herum', 'holen', 'zimmer', 'schaffen', 'suchen', 'tragen', 'steigen', 'warm', 'richtung', 'warten', 'bestimmen', 'rennen', 'öffnen', 'tief', 'sache', 'natur', 'biene', 'fliegen', 'gemeinsam', 'ding', 'gerne', 'schlagen', 'fangen', 'wichtig', 'angst', 'freuen', 'direkt', 'bett', 'familie', 'lang', 'bisschen', 'tun', 'schritt', 'opa', 'hab', 'retten', 'licht', 'grün', 'frage', 'verschwinden', 'schulter', 'leise', 'stunde', 'springen', 'blume', 'meist', 'gut', 'lesen', 'umwelt', 'platz', 'land', 'ben', 'fuß', 'nacht', 'fenster', 'klasse', 'bitte', 'draußen', 'all', 'straße', 'himmel', 'folgen', 'können', 'echt', 'glück', 'strand', 'bauen', 'schnell', 'geschichte', 'schreiben', 'problem', 'schnee', 'bruder', 'verlieren', 'eis', 'wachsen', 'schütteln', 'spielen', 'traurig', 'klaren', 'wind', 'vogel', 'reden', 'heraus', 'schwer', 'groß', 'lernen', 'riesig', 'lina', 'beobachten', 'entdecken', 'name', 'bemerken', 'blau', 'zukunft', 'lieb', 'paul', 'stein', 'stück', 'leon', 'flüstern', 'spüren', 'rot', 'neu', 'lässt', 'schlafen', 'hilfe', 'erinnern', 'grinsen', 'schwester', 'heben', 'schwarz', 'überall', 'nämlich', 'herz', 'haar', 'treffen', 'stimmen', 'hängen', 'minute', 'ankommen', 'tatsächlich', 'fahrrad', 'vorbei', 'anna', 'arbeit', 'plastik', 'marie', 'ander', 'insel', 'erreichen', 'abend', 'alleine', 'bild', 'zuhause', 'lara', 'klingen', 'buch', 'stark', 'arbeiten', 'mund', 'nennen', 'stecken', 'drücken', 'wiese', 'irgendwie', 'überlegen', 'kaufen', 'schüler', 'ändern', 'reichen', 'schlimm', 'planet', 'ziemlich', 'atmen', 'starren', 'stolz', 'manchmal', 'obwohl', 'aufregen', 'nase', 'thema', 'bein', 'vorsichtig', 'geld', 'sterben', 'nähern', 'heißen', 'handy', 'freundin', 'erkennen', 'merken']

# %%
"""
Text Cleaning:
Remove Remove entity's names,Propn and Adverbs
Might take some time
"""

frequent_verbs=[]
corpus = []
for i in range(len(df)):
    lemmas_l=[]
    persons=[]
    
    #entitie preprocessing:
    # We want to get rid of all the words which represents the name
    for m in range(len(df['entities'][i])):
        if df['entities'][i][m][1]=='PER':
            persons.append(df['entities'][i][m][0])
    
    # Here we already remove the propn, entity names and verbs
    for j in range(len(df['lemmas'][i])):
        if df['pos'][i][j]!="PROPN" and (df['lemmas'][i][j] not in persons)and (df['lemmas'][i][j].lower() not in most_freq) and df['pos'][i][j]!="ADV":
            lemmas_l.append(df['lemmas'][i][j])
    corpus.append(' '.join(lemmas_l))

# %%
"""
extract key words for each story : Top 25

Note:the words are not theme related and only present the elements of the story.
We could generate WordCloud to make it more visualize
"""
# it's possible to change the number of feature words here
result = keyword(corpus, 25)

for i in range(len(df)):
    print('Story ID:', df['story_id'][i], result[i])
    
df2=pd.DataFrame({'story_id':df['story_id'],'keywords':result})

df2.to_csv('Keywords.csv',encoding = 'ISO-8859-1')
df2
# Out:
# Story ID: 19 ['wolke', 'bulk', 'zukunftsmusik', 'spiegel', 'kohlendioxid', 'sonnenschirme', 'atmosphäre', 'radio', 'schwefel', 'ägypter', 'co', 'pinguin', 'weltall', 'schubser', 'schützend', 'ring', 'ventil', 'senden', 'sonnenlicht', 'einmachglas', 'forscher', 'hegen', 'reflektieren', 'vulkan', 'platzen']
# Story ID: 21 ['dorf', 'bürgermeister', 'schneien', 'wettbewerb', 'pflanzen', 'milliarde', 'kohlendioxid', 'assistent', 'pförtner', 'rathaus', 'computer', 'taschenrechner', 'schwitzen', 'zahl', 'tüte', 'achmed', 'dezembermonate', 'gießerei', 'pflanzenmathilda', 'rasenmäher', 'umwandeln', 'auslachen', 'mikrofon', 'klassenkameraden', 'lehrerpult']
# Story ID: 24 ['frosch', 'stiefmutter', 'wolf', 'prinz', 'hexe', 'feige', 'suv', 'weglaufen', 'könig', 'fluch', 'stiefschwester', 'gemüsebeet', 'serie', 'ungeheuer', 'märchen', 'bekämpfen', 'fliege', 'belästigen', 'kehlsack', 'forscher', 'erwidern', 'heimat', 'miene', 'derjenige', 'end']
# Story ID: 25 ['geist', 'schlafzimmer', 'lebensstil', 'wesen', 'himbeere', 'eiszeit', 'geländewagen', 'kohle', 'industrialisierung', 'wurst', 'verzicht', 'schelten', 'teller', 'balkontür', 'currywurst', 'erdelfe', 'heimwerken', 'kaltzeit', 'milchprodukte', 'vorangegangen', 'zukünftig', 'mütze', 'rad', 'buffet', 'kantine']
# Story ID: 125 ['zelt', 'zeichnung', 'zeichnen', 'band', 'professor', 'jungs', 'karte', 'lucios', 'handgelenk', 'traum', 'heft', 'operation', 'schuh', 'bus', 'mosaikschwanzratte', 'simulation', 'zeichenheft', 'begegnung', 'mission', 'doppelgänger', 'zelten', 'niemals', 'schlucken', 'verknüpfen', 'spät']
# Story ID: 131 ['wildbienen', 'erbesmödl', 'platterbsenmörtelbiene', 'platterbse', 'kompendium', 'melanies', 'plattner', 'verwandlungszauber', 'handy', 'zaun', 'schimmer', 'güte', 'abwimmeln', 'bambusröhrchen', 'braunbeige', 'gartenbank', 'geblümt', 'holzbiene', 'pelzbiene', 'schraubglas', 'vergrößerungszauber', 'art', 'wund', 'quasi', 'versichern']
# Story ID: 132 ['zug', 'sandstein', 'magnet', 'ferrofluid', 'sitzplatz', 'bewusst', 'quantenphysik', 'zeitreisen', 'zeitreisende', 'reisen', 'glaube', 'ergeben', 'gepäck', 'ungeduld', 'wasserflasche', 'reise', 'kramen', 'hafen', 'elektroteile', 'wagon', 'zugabteils', 'freiheit', 'glänzend', 'bescheißen', 'sandkörnchen']
# Story ID: 138 ['vorgarten', 'filzpantoffeln', 'steinwüsten', 'häuserreihe', 'putzeimer', 'freitag', 'megaphon', 'klassenbeste', 'meinung', 'kraftwerk', 'knast', 'kohlekraftwerk', 'future', 'klassenlehrerin', 'flugblatt', 'besserwisser', 'habs', 'regenwasser', 'zwilling', 'eisbären', 'dampfwolken', 'dummbleiber', 'gasira', 'protestfahrradtour', 'reell']
# Story ID: 139 ['seppeldeppe', 'bussard', 'brax', 'putt', 'trecker', 'hä', 'motorsäge', 'bauer', 'flügel', 'gackert', 'uhu', 'kabel', 'rat', 'stamm', 'käfer', 'horst', 'reng', 'kiste', 'schlachtruf', 'zweig', 'heran', 'dick', 'sitzung', 'schmetterling', 'dicke']
# Story ID: 140 ['flughafen', 'flugfeld', 'naturschutzgebiet', 'virus', 'bürgermeister', 'flugzeug', 'meinung', 'gelände', 'quarantäne', 'bahnhof', 'betrieb', 'abgas', 'öfter', 'fortschritt', 'verkehr', 'überlegt', 'medikament', 'zug', 'ansteckungsgefahr', 'bahnlinie', 'erholungsgebiet', 'flugfelds', 'landebahnen', 'umfrage', 'erwachsene']
# Story ID: 142 ['yachuk', 'vikunjas', 'lehrer', 'hang', 'lastwagen', 'inti', 'spanier', 'schülerin', 'tafel', 'abrutschen', 'säge', 'malen', 'begraben', 'ladefläche', 'nachbardorf', 'berg', 'geröll', 'berichten', 'ragen', 'vorfahr', 'schaf', 'chicha', 'gewebt', 'herunterstürzende', 'inka']
# Story ID: 177 ['flitzi', 'feuer', 'ast', 'zweig', 'anni', 'sage', 'flamme', 'eichhörnchen', 'bank', 'wäldchen', 'schachtel', 'rauch', 'hütte', 'zigarette', 'zögern', 'versuche', 'sitze', 'weile', 'messer', 'vorrat', 'eichhörnchenfamilie', 'gipsbein', 'golfplatz', 'hörnchen', 'stürme']
# Story ID: 180 ['demo', 'mega', 'vermutlich', 'projekt', 'april', 'abhauen', 'bock', 'hasse', 'einsparen', 'plakat', 'bandprobe', 'clean', 'fettig', 'gerockt', 'lieblingsphantasie', 'niederländer', 'ocean', 'xxx', 'mai', 'art', 'pfirsich', 'rochen', 'studentin', 'up', 'sowieso']
# Story ID: 185 ['kunstfell', 'klimatagebuch', 'fünftklässlerin', 'supermarktbesitzer', 'ökotante', 'supermarkt', 'jacke', 'fell', 'folie', 'herrn', 'benutzen', 'abfüllstationen', 'erzrivalin', 'kirmascheks', 'sortiment', 'vernichtend', 'virus', 'verbündet', 'verwöhnt', 'handeln', 'oftmals', 'strohhalme', 'tagebuch', 'garage', 'kapuze']
# Story ID: 187 ['projekttag', 'herrn', 'anrufen', 'laufe', 'vincent', 'ausfallen', 'absagen', 'kleidertausch', 'total', 'untergehen', 'englischtest', 'mülldienst', 'schulküche', 'strafe', 'mitbringen', 'bauernhof', 'schaden', 'forscher', 'kleid', 'klassenlehrerin', 'halb', 'urlaub', 'klimaforscher', 'anziehsache', 'aussuchen']
# Story ID: 188 ['maus', 'wubbjes', 'wurmhumus', 'abfall', 'pappe', 'grummelig', 'mistwürmer', 'müllmonster', 'eisenbahn', 'nährstoff', 'kellerasseln', 'misthaufen', 'verdünnen', 'wubbjeland', 'regenwürmer', 'stoff', 'lupe', 'gelaunt', 'fies', 'bakterie', 'kompost', 'futtern', 'fressen', 'gang', 'acker']
# Story ID: 189 ['präsentation', 'honkis', 'lerntafel', 'navids', 'oberstadt', 'geschichtsunterricht', 'neufrankfurt', 'schicksalsjahr', 'aufzug', 'furche', 'packung', 'interview', 'seufzen', 'video', 'ameise', 'verpesten', 'animation', 'anoma', 'ingenieursunterricht', 'lerngruppe', 'lernhalle', 'navidpaula', 'schultrakt', 'siepaula', 'ustadt']
# Story ID: 194 ['sternchen', 'thoma', 'bockel', 'nistkasten', 'rad', 'see', 'trecker', 'pferd', 'ninas', 'flehmt', 'schnuckeline', 'streuobstwiese', 'gras', 'spritzen', 'schwein', 'leiter', 'güllefass', 'stute', 'gatter', 'bauer', 'stall', 'wurzel', 'naturschutzgebiet', 'seltene', 'stürzen']
# Story ID: 198 ['magazin', 'gang', 'allens', 'artikel', 'mobilität', 'grünebikergang', 'konferenz', 'schiff', 'ballaststoffe', 'sabine', 'speisekammer', 'hendrik', 'passant', 'per', 'kerosin', 'aktion', 'km', 'radeln', 'einkauf', 'firma', 'direktor', 'liter', 'auswirkung', 'konsequenz', 'regenbogen']
# Story ID: 199 ['erwachen', 'gaias', 'miteinander', 'wund', 'gold', 'freude', 'grippe', 'sonnenkind', 'geschenk', 'geschehen', 'fieber', 'taten', 'landschaft', 'hereinspaziert', 'kirschsaftschorle', 'schüttelfrost', 'sonnenkinder', 'erschaffen', 'krieg', 'wundervoll', 'bereichern', 'pate', 'wertschätzung', 'hinterfragen', 'jedesmal']
# Story ID: 201 ['wunsch', 'radiostimme', 'tischtennisplatte', 'offensichtlich', 'egoistisch', 'riegel', 'geschöpf', 'team', 'beleidigen', 'nachricht', 'rollstuhl', 'toilette', 'ernsthaft', 'pause', 'person', 'flügel', 'oberkörperfrei', 'originell', 'utopie', 'völkerball', 'weggewünscht', 'unterbrechen', 'wählen', 'aufzug', 'tischtennisplatten']
# Story ID: 202 ['onkel', 'baustelle', 'baustellenleiter', 'schulranzen', 'tischtennisplatte', 'einpacken', 'fabrik', 'furzkissen', 'samenkorn', 'hecke', 'beutel', 'blumenbeet', 'gummibärchen', 'säule', 'blütenblätter', 'bonbon', 'komisch', 'cent', 'schulhof', 'bonbonpapier', 'bushaltestelle', 'pflänzchen', 'blättern', 'erwachsene', 'handflächen']
# Story ID: 203 ['andrea', 'fahrschein', 'iss', 'space', 'jet', 'deck', 'sj', 'uhram', 'erlaubnis', 'antrag', 'klimaerwärmung', 'erneuerbaren', 'erziehungsberechtigten', 'jonathans', 'sjay', 'touchscreen', 'versorgungsfrachter', 'klimakatastrophe', 'pa', 'stundenplan', 'strom', 'termin', 'notizbuch', 'brief', 'verkünden']
# Story ID: 207 ['kid', 'schulkleidung', 'teich', 'umwelttempel', 'schulfest', 'modell', 'umweltcoach', 'erhalten', 'inzwischen', 'mitschüler', 'republik', 'schülerin', 'engagieren', 'produzieren', 'coaches', 'fischsterben', 'goethegymnasium', 'modenschau', 'planetgarten', 'praktikantin', 'recyceltem', 'recycelten', 'schulfrei', 'umweltteam', 'unterrichtsfreien']
# Story ID: 214 ['internetgruppe', 'kreuzfahrt', 'gruppenmitglieder', 'laune', 'mitglied', 'konkrete', 'mitmachen', 'urlaub', 'million', 'dieselmotor', 'karibikkreuzfahrt', 'kontrollausschuss', 'zugefroren', 'gruppe', 'heizung', 'winter', 'ernstes', 'störenfriede', 'möglichst', 'klimaschutz', 'erwachsene', 'erfolg', 'buchen', 'aktion', 'gebrauchen']
# Story ID: 215 ['figur', 'spiel', 'spielfigur', 'professor', 'konsole', 'sanduhr', 'journalistin', 'held', 'kuh', 'bildschirm', 'masttieranlage', 'roboterstimme', 'bildschirms', 'helm', 'fleisch', 'landwirt', 'gerät', 'erscheinen', 'luke', 'thermometer', 'milch', 'raumschiff', 'übertragen', 'treibhauseffekt', 'avatar']
# Story ID: 216 ['enkelin', 'frikadelle', 'peacezeichen', 'elisenstraße', 'ellis', 'foto', 'parkplatz', 'gabel', 'gas', 'buttermilch', 'guerilla', 'gardening', 'polizist', 'aktion', 'piepen', 'rasen', 'annelis', 'privatgrundstück', 'salatblatt', 'schmuckkasten', 'siebzigjährige', 'tofufrikadellen', 'krieg', 'moos', 'heimlich']
# Story ID: 217 ['klimafee', 'bürgermeister', 'hansen', 'festsaal', 'windpark', 'mädel', 'strom', 'achtung', 'dorfbewohner', 'wettbewerb', 'kerze', 'dorfkrug', 'grünfrieden', 'stromausfall', 'gebrüll', 'dorf', 'plakat', 'unwetter', 'prompt', 'besprechen', 'gasöfen', 'gottesdienst', 'oldie', 'zombie', 'zweckgebunden']
# Story ID: 219 ['ball', 'matuschkes', 'tor', 'stall', 'herrn', 'gast', 'party', 'fußbälle', 'stalltor', 'wurst', 'fußball', 'zigarre', 'gruselig', 'schreiten', 'lappe', 'schießen', 'hinten', 'rüber', 'schokolade', 'quietschen', 'dick', 'teller', 'ananassaft', 'benzinschleudern', 'elfeinhalb']
# Story ID: 224 ['supermarkt', 'thoma', 'geschwister', 'altpapier', 'ente', 'klimadetektive', 'knörtzi', 'kunde', 'held', 'superkräfte', 'sortieren', 'abfall', 'bär', 'park', 'gürteltasche', 'zwergschwein', 'bloß', 'gebrauchen', 'rosa', 'plan', 'kohlendioxid', 'behältnisse', 'wärmestrahlen', 'färben', 'lose']
# Story ID: 225 ['förster', 'großvater', 'großmutter', 'australien', 'wildschwein', 'pferd', 'enkelin', 'nahrung', 'waldbesucher', 'großeltern', 'flamme', 'feuer', 'waldboden', 'wurzel', 'holz', 'blättern', 'wachstum', 'pilz', 'erstaunt', 'ausscheidung', 'enkeltochter', 'specht', 'maus', 'buche', 'forsthaus']
# Story ID: 226 ['düne', 'sand', 'opi', 'autohaus', 'sturm', 'bank', 'pullovermann', 'schotter', 'gucken', 'villa', 'ferien', 'kakao', 'unwetter', 'großeltern', 'spritzen', 'see', 'freiherr', 'insulaner', 'klimainsel', 'lehmweg', 'lütt', 'silvesterhut', 'strandhafer', 'bürgermeisterin', 'nachbarinsel']
# Story ID: 228 ['atreya', 'gewitter', 'traum', 'weltenbaum', 'merkwürdig', 'donnergrollen', 'virtuellen', 'schüssel', 'hologramm', 'blümchen', 'ertönt', 'lichtung', 'blitz', 'irritieren', 'pfad', 'weile', 'schutz', 'brei', 'wolkenkratzer', 'großmutter', 'beliebig', 'frühlingsblumen', 'existieren', 'knorrig', 'krachen']
# Story ID: 233 ['großeltern', 'ferien', 'pizza', 'seehundebaby', 'kreuzfahrt', 'tasche', 'backofen', 'heuler', 'tollen', 'internet', 'lust', 'schnecken', 'papier', 'sage', 'belohnung', 'meerestiere', 'tourist', 'wal', 'einrichten', 'modern', 'altöl', 'bräune', 'kutterfahrt', 'seeluft', 'sehenswürdigkeiten']
# Story ID: 237 ['institut', 'dr', 'brief', 'forschung', 'bildhauer', 'leonardo', 'afrika', 'zitat', 'deutschland', 'hund', 'note', 'universität', 'aline', 'forschungsbericht', 'heimer', 'regierung', 'großmutter', 'tag', 'telefon', 'bericht', 'schulprojekt', 'gedicht', 'zwölf', 'guten', 'längst']
# Story ID: 248 ['marshörner', 'marshorndung', 'mars', 'treibstoff', 'aufzug', 'dupont', 'monsieur', 'notizheft', 'marshörnern', 'freundin', 'rakete', 'beweis', 'jodelmusik', 'weltall', 'einbrecher', 'ausnahme', 'nebenbei', 'herd', 'durchs', 'bekreuzigen', 'gemüseköchin', 'giraffenmist', 'jonglierobst', 'kasserole', 'lastenaufzug']
# Story ID: 251 ['ignorant', 'tränengasnebel', 'umweltaktion', 'grau', 'wunde', 'eintönig', 'krankenwagen', 'park', 'nebelwand', 'nachhause', 'farbeimer', 'geräusch', 'abwechslung', 'raus', 'pinsel', 'langweilig', 'brocken', 'veränderung', 'relativ', 'einpflanzen', 'anwerben', 'halbglatze', 'vandalismus', 'tuch', 'laufe']
# Story ID: 292 ['köhlchen', 'geist', 'rauchsäule', 'schweben', 'magische', 'rote', 'glubschte', 'säubern', 'mustern', 'strom', 'fressen', 'schleichen', 'auftrag', 'flitzen', 'blättermädchen', 'bläschen', 'haarspange', 'kohlenstoff', 'schlängeln', 'müde', 'energie', 'auspuff', 'abdrehen', 'parkplatz', 'magie']
# Story ID: 293 ['schaufel', 'wrack', 'fressen', 'fisch', 'erdöl', 'norden', 'tauchlehrer', 'benzin', 'schiff', 'koralle', 'öl', 'urlaub', 'verbrennen', 'sand', 'doofi', 'falterfisch', 'förmchen', 'hotelbesitzer', 'kinderbuch', 'sandkuchen', 'seeanemone', 'festgewachsen', 'besteck', 'schwimmen', 'bahn']
# Story ID: 294 ['hafen', 'schatzinsel', 'seeschlangen', 'kran', 'maschine', 'schiff', 'flugzeug', 'klimaanlagen', 'seeschlange', 'steuerhaus', 'anschnallen', 'kokosnuß', 'südsee', 'treibend', 'sizilien', 'ausgewachsen', 'flughafen', 'schwimmend', 'tablett', 'projekt', 'besuchen', 'katamaran', 'landebahn', 'mast', 'mirondas']
# Story ID: 296 ['alena', 'lösung', 'umso', 'co', 'einfluss', 'nasa', 'wissenschaftler', 'sinn', 'einsetzen', 'zeitung', 'fange', 'sitze', 'industriewerke', 'infoveranstaltung', 'messwerten', 'temperatur', 'wärme', 'forscher', 'politiker', 'bühne', 'tablet', 'irren', 'rede', 'kalifornien', 'lauffeuer']
# Story ID: 297 ['fisch', 'lehrer', 'vögelchen', 'libelle', 'kapitel', 'kuh', 'hering', 'religion', 'fleisch', 'bo', 'kilo', 'töten', 'saal', 'mücke', 'insekt', 'brücke', 'tierchen', 'bolzplatz', 'grünland', 'klohäuschen', 'kuhweide', 'lagerraum', 'larissa', 'begegnung', 'aquakultur']
# Story ID: 299 ['opapa', 'großvater', 'menschheit', 'natürlich', 'türe', 'betrachtung', 'marode', 'bevölkerung', 'gebäude', 'kraft', 'großteil', 'krise', 'enkel', 'überleben', 'beschaffenheit', 'opapas', 'strapazierfähig', 'eilen', 'gesund', 'bezeichnen', 'umgebung', 'ableger', 'minimum', 'unbewohnt', 'ort']
# Story ID: 300 ['fee', 'bla', 'bagger', 'bastelstunde', 'pinsel', 'erderwärmung', 'schüssel', 'baggerfahrer', 'stoff', 'produzieren', 'kleid', 'blumenwiese', 'apfel', 'gefährt', 'bemühen', 'backpapier', 'brünette', 'burger', 'bürgerzentrum', 'fingerschnipsen', 'hexerei', 'rädchen', 'veganen', 'geschäft', 'positiv']
# Story ID: 302 ['eisbären', 'arktisraupe', 'arktis', 'forscher', 'eisbergen', 'eisscholle', 'inzwischen', 'schlitten', 'polarkappen', 'bord', 'lebensraum', 'eisbär', 'schiff', 'foto', 'malen', 'nordpol', 'dr', 'seehunde', 'süß', 'spaß', 'hintergrund', 'werkstatt', 'deck', 'werkzeug', 'plakat']
# Story ID: 305 ['wal', 'tasche', 'stofftasche', 'logo', 'plastiktüten', 'bags', 'york', 'bb', 'beachboy', 'isis', 'tüte', 'new', 'video', 'reporter', 'verkäuferin', 'amerikaner', 'magen', 'zupfen', 'handy', 'packung', 'vermisste', 'supermarkt', 'einkaufen', 'sorry', 'aufgeschlitzt']
# Story ID: 306 ['matrose', 'vertrag', 'schiff', 'kühlschrank', 'dicke', 'auftraggeber', 'elektrogeräten', 'hodock', 'komplize', 'technikmarkt', 'besitzer', 'elektroschrott', 'händler', 'käpt', 'müllhalde', 'oberteil', 'erwidern', 'arbeiterin', 'einzelteile', 'akku', 'container', 'qualität', 'daraufhin', 'hafen', 'gleich']
# Story ID: 307 ['milliardärin', 'bine', 'reh', 'müssen', 'google', 'verbrauchen', 'aktie', 'mysterywald', 'server', 'servern', 'datum', 'energie', 'paddeln', 'zaun', 'tee', 'schnur', 'film', 'geheimnis', 'firma', 'wolf', 'ergänzen', 'gegend', 'bird', 'hundertwasser', 'jones']
# Story ID: 308 ['jolle', 'boot', 'segeln', 'meeresschildkröte', 'segel', 'delfin', 'welle', 'fischermesser', 'köcher', 'seestern', 'schildkröte', 'flosse', 'messer', 'ufer', 'steg', 'gummistiefel', 'eimer', 'krebs', 'deutlich', 'gewaltig', 'bootsrand', 'festmacherseil', 'gruuu', 'heck', 'ho']
# Story ID: 310 ['mücke', 'rabe', 'troll', 'kuh', 'elfe', 'zahl', 'seltsam', 'artensterben', 'weinen', 'entdeckung', 'zehnjährigen', 'spaziergang', 'fabelwesen', 'flügel', 'schroff', 'nummer', 'beherrschen', 'insekt', 'eisbären', 'chor', 'wiesengrund', 'zipfel', 'forsthaus', 'mathematik', 'buchstabe']
# Story ID: 315 ['doktor', 'bus', 'fähigkeit', 'mappe', 'kettenreaktion', 'kettenreaktionen', 'wohnung', 'papier', 'umfallen', 'treppe', 'globus', 'kartoffel', 'kette', 'tisch', 'finger', 'ereignisketten', 'golfstrom', 'besonderes', 'fremde', 'himalaya', 'spielzeugautos', 'turnen', 'vorschreiben', 'fluss', 'nachdenken']
# Story ID: 316 ['elektronik', 'benutzen', 'ninja', 'atmosphäre', 'glas', 'hurrikan', 'experiment', 'zb', 'sonne', 'superheldin', 'ca', 'treibhaus', 'kernfusion', 'schicht', 'ungefähr', 'durchmesser', 'energie', 'million', 'konsole', 'superheld', 'zerstören', 'temperatur', 'kohlendioxid', 'sand', 'gefahren']
# Story ID: 319 ['professor', 'baumhöhle', 'hund', 'ampel', 'stresemannplatz', 'zerren', 'gegenwart', 'flyer', 'leine', 'nahezu', 'straßenbahn', 'offene', 'ullrich', 'abdrucken', 'ausgabe', 'hundes', 'hupkonzert', 'knacksen', 'mülltüte', 'merkwürdig', 'verrücken', 'doofe', 'herunterfallen', 'gegenteil', 'altern']
# Story ID: 320 ['it', 'be', 'let', 'braunkohlewerk', 'magie', 'urwald', 'werk', 'tor', 'liane', 'ast', 'reporterin', 'dschungel', 'rascheln', 'blättervorhang', 'braunkohlewerks', 'zauberbohne', 'grüne', 'gestrüpp', 'sprießen', 'demonstrant', 'fensterbank', 'blättern', 'klimabohne', 'teufel', 'neubaugebiet']
# Story ID: 380 ['tante', 'falke', 'flugshows', 'poster', 'küken', 'volieren', 'anbau', 'scherbe', 'falknerei', 'stadtjunge', 'schale', 'erwidern', 'wurm', 'besucher', 'bank', 'flugplatz', 'show', 'handschuh', 'futter', 'eintopf', 'schenkel', 'schotterweg', 'bestätigen', 'blödmann', 'schere']
# Story ID: 381 ['schneien', 'rollator', 'schneemann', 'traum', 'holles', 'möbelstücks', 'rückwand', 'decke', 'kleid', 'kleiderschrank', 'jahreszeiten', 'erschrecken', 'hasste', 'sand', 'bettdecken', 'boshaftigkeit', 'fahrradtrinkflasche', 'schneetag', 'tollen', 'trotzig', 'achselzuckend', 'ältere', 'zeug', 'alte', 'schrank']
# Story ID: 382 ['chipstüte', 'kiel', 'das', 'dschungel', 'handfläche', 'schreien', 'sara', 'weine', 'umweltschutz', 'schwindel', 'typ', 'panisch', 'träne', 'ja', 'folge', 'berlin', 'zusammenarbeiten', 'schluchzen', 'eray', 'grenzzaun', 'geschlossen', 'gebäude', 'schuß', 'straßenlaterne', 'wasserkocher']
# Story ID: 383 ['schlachthof', 'büffet', 'kreiszeitung', 'grillfest', 'ausflug', 'brötchen', 'lehrerin', 'zettel', 'schwein', 'würstchen', 'käse', 'fleisch', 'transparent', 'bremer', 'fotoapparat', 'kulturzentrum', 'lasagne', 'erdbeere', 'board', 'bestellen', 'handy', 'gabel', 'arbeitskleidung', 'army', 'flatrail']
# Story ID: 384 ['schlamm', 'fee', 'höhle', 'schlammbrocken', 'stinkfilzer', 'tageland', 'tautropfen', 'zutat', 'frosch', 'flügel', 'nenn', 'qua', 'zapotheker', 'berg', 'öffnung', 'zauber', 'wetter', 'schillernd', 'verwüsten', 'maschine', 'regnen', 'glitzerte', 'tropfen', 'bückten', 'feenhügel']
# Story ID: 387 ['robbe', 'möwe', 'mole', 'pc', 'vortrag', 'unfassbar', 'kleinohr', 'gemeinschaft', 'nordsee', 'hinten', 'klärschlamm', 'peppers', 'ritzen', 'gucken', 'zone', 'nass', 'aufsatz', 'wusstet', 'mitschüler', 'arme', 'leid', 'sand', 'düne', 'freitag', 'hasse']
# Story ID: 390 ['großmutter', 'magd', 'kästchen', 'pferd', 'amulett', 'verstecken', 'verbinden', 'tagebuch', 'bestie', 'blütenessenzen', 'essenz', 'habenlara', 'heilend', 'heilstein', 'heilsteine', 'heilsteinen', 'kramladen', 'pferdehof', 'sir', 'datum', 'reh', 'kraft', 'kronleuchter', 'kräuterfrau', 'nichte']
# Story ID: 391 ['pupse', 'pupsen', 'paule', 'pupen', 'pupste', 'kaputt', 'bauchweh', 'handy', 'klassenzimmer', 'methan', 'klara', 'maisheuschreckeneintopf', 'pups', 'pupsfrei', 'pupst', 'sonja', 'waschecht', 'weiterlesen', 'platzen', 'suchmaschine', 'verdauung', 'aufstehen', 'fabrik', 'ball', 'huf']
# Story ID: 392 ['kolibri', 'nummer', 'video', 'telefonieren', 'moema', 'feuer', 'käfig', 'livestream', 'handy', 'eisbären', 'nordpol', 'robbe', 'kapitel', 'kommentar', 'hitzejahr', 'marton', 'müllinsel', 'regenwald', 'mutig', 'netz', 'account', 'ängstlich', 'anstatt', 'hi', 'nektar']
# Story ID: 393 ['maya', 'luftschiff', 'hütte', 'seuche', 'öl', 'wüste', 'siedlung', 'düne', 'geisterstadt', 'sandplankton', 'erstaunlich', 'sand', 'achselzuckend', 'overall', 'dad', 'schleuse', 'schiefgehen', 'seitlich', 'afrika', 'erdöl', 'alex', 'elektromotoren', 'kamm', 'kapstadt', 'kolmannskuppe']
# Story ID: 394 ['stadtwald', 'film', 'wohnraum', 'helles', 'block', 'bürgermeister', 'gedicht', 'song', 'kohlendioxid', 'klimawandelprojekt', 'serafinas', 'songtext', 'stadtwaldes', 'aufnahme', 'melodie', 'jury', 'klavier', 'zerfallen', 'meinung', 'singen', 'saal', 'kamera', 'publikum', 'sauerstoff', 'ehe']
# Story ID: 396 ['lager', 'polizist', 'video', 'aufbringen', 'weinen', 'entgegen', 'helikopter', 'verzweifeln', 'situation', 'tochter', 'erkannt', 'ferne', 'beeinflussen', 'handy', 'wahrscheinlich', 'brand', 'mehrer', 'kommissar', 'chance', 'brennend', 'account', 'überfordern', 'instagram', 'inständig', 'gegenteil']
# Story ID: 398 ['fibra', 'jordis', 'kapsel', 'naturforscherin', 'apfel', 'greifen', 'notizbuch', 'haha', 'he', 'fantastisch', 'ebenfalls', 'unkraut', 'herumbastelt', 'hoh', 'roboterpflanze', 'tem', 'temetaria', 'zeitkapsel', 'blättern', 'elektronik', 'jaa', 'montieren', 'tablet', 'stupst', 'samen']
# Story ID: 399 ['doktorfisch', 'flosse', 'meeresschildkröte', 'hai', 'panzer', 'reef', 'meeresbewohner', 'blubbern', 'fischer', 'wallriffschildkröte', 'koralle', 'barrier', 'fischerboot', 'great', 'mikroplastik', 'schwanzflosse', 'riff', 'qualle', 'maul', 'krake', 'schildkröte', 'fischernetze', 'urenkel', 'artikel', 'möwe']
# Story ID: 400 ['rabe', 'großtante', 'ring', 'gott', 'krächzen', 'huhn', 'gelbauges', 'feder', 'grünauge', 'malvas', 'weiße', 'naturkatastrophen', 'sturm', 'ix', 'jaguarweibchen', 'verheerend', 'fernseher', 'klappe', 'inselgruppe', 'wilderer', 'versammlung', 'wirbelsturm', 'picken', 'rasch', 'kralle']
# Story ID: 401 ['schildkröte', 'kokospalmen', 'samen', 'höhle', 'großmutter', 'delphin', 'dorf', 'kokospalme', 'bäcker', 'wasserlebewesen', 'säen', 'ozean', 'hotelanlagen', 'ernten', 'tourist', 'hoffnung', 'pflanzen', 'armband', 'magische', 'wiedersehen', 'tiefe', 'ziel', 'heldin', 'kokosnussbaumsamen', 'mutterjasmine']
# Story ID: 403 ['yashas', 'berg', 'gipfel', 'rajas', 'käsebrote', 'fremd', 'buschig', 'sperren', 'augenbraue', 'linie', 'träne', 'tritt', 'geschlecht', 'goldaugen', 'keli', 'sprache', 'aufragen', 'grenze', 'entscheidung', 'felswand', 'steinbrocken', 'stupst', 'wenden', 'bergauf', 'fels']
# Story ID: 406 ['brunnen', 'dorf', 'berg', 'feuerwerk', 'neujahrsnacht', 'ruqi', 'wünsche', 'hütte', 'regenzeiten', 'erleben', 'weihnachtsferien', 'österreich', 'feld', 'hochland', 'lebenilhan', 'nomade', 'ostafrika', 'trinken', 'trinkwasser', 'freundin', 'geschwister', 'sturm', 'jalousie', 'kamel', 'müde']
# Story ID: 407 ['waldgeist', 'ramiru', 'waldgeister', 'apfelbäumchen', 'borkenherz', 'wesen', 'regenwürmer', 'streber', 'pflanzen', 'botanische', 'turnbeutel', 'mütze', 'brust', 'dorftrottel', 'sportbeutel', 'birnbaum', 'apfel', 'kettensäge', 'bäumchen', 'geschöpf', 'magisch', 'gebären', 'frei', 'wispern', 'borkige']
# Story ID: 408 ['hirsch', 'baummarder', 'rat', 'müllsack', 'marder', 'pfad', 'erneut', 'schämen', 'saubermacher', 'sonderkommision', 'wilma', 'reife', 'schlagartig', 'sack', 'säubern', 'lichtung', 'waldbewohner', 'schlange', 'dose', 'rasch', 'rotieren', 'wahrhaftig', 'harmonie', 'scheren', 'spezies']
# Story ID: 409 ['demonstration', 'matheaufgaben', 'brot', 'demonstrieren', 'foto', 'beschließen', 'fluß', 'sturm', 'irgendwas', 'ddr', 'zucken', 'mehrer', 'zeitzeugen', 'fotoalben', 'beißen', 'lehrer', 'fernbedienung', 'schlitten', 'vollkommen', 'winter', 'müsli', 'beeinflussen', 'irgendwelchen', 'marktplatz', 'puh']
# Story ID: 410 ['alufolie', 'buche', 'müllbeutel', 'park', 'getränkedosen', 'zugegeben', 'mühe', 'treppenhaus', 'zeichnen', 'getränkedose', 'ignorante', 'kaufkraft', 'müffelte', 'eingangstür', 'kuh', 'weißt', 'beid', 'routiniert', 'verpackung', 'direktorin', 'bisherig', 'kg', 'schulgebäude', 'spinner', 'umweltschutz']
# Story ID: 411 ['oleg', 'taschenlampe', 'container', 'transporter', 'zaun', 'lebensmittel', 'henni', 'fietes', 'supermarkt', 'polizei', 'batterie', 'klauen', 'rucksack', 'maliks', 'rhabarbertörtchen', 'kofferraum', 'polizist', 'tonne', 'juni', 'tafel', 'gerettet', 'klo', 'mitkommen', 'chucks', 'containern']
# Story ID: 412 ['flasche', 'schüssel', 'mangobaum', 'my', 'tante', 'pizza', 'are', 'ausladend', 'you', 'nachricht', 'reis', 'geld', 'ausmalen', 'change', 'fladen', 'flaschenpost', 'friends', 'help', 'motorrad', 'plenty', 'we', 'genüsslich', 'dunkelgrün', 'löwe', 'schulkameraden']
# Story ID: 414 ['thoma', 'schuh', 'studio', 'spargel', 'nachhaltig', 'turnschuh', 'globalisierung', 'solarpanele', 'südasien', 'berlin', 'ohrringe', 'rechts', 'toll', 'tshirt', 'produkt', 'leggings', 'tshirts', 'euro', 'ozonschicht', 'schnürsenkel', 'flohmarkt', 'günstig', 'weiss', 'lade', 'technologie']
# Story ID: 428 ['igel', 'schildkröte', 'fuchs', 'kaninchen', 'laubhaufen', 'näschen', 'norden', 'reservat', 'weiher', 'wittern', 'winter', 'see', 'sees', 'küken', 'winterschlaf', 'menschenkinder', 'spatz', 'zaun', 'häuschen', 'nest', 'fein', 'verlassen', 'nilgans', 'obststräucher', 'schnüffelnda']
# Story ID: 429 ['kuppel', 'patrouille', 'overall', 'festland', 'beigen', 'klassenkameraden', 'blinzeln', 'dauern', 'ton', 'sitz', 'raum', 'mentor', 'personal', 'pulk', 'taucher', 'uboot', 'verräter', 'löwe', 'berühren', 'entnerven', 'schwatzen', 'unterricht', 'lehrer', 'seltsames', 'trüben']
# Story ID: 432 ['robbe', 'muschel', 'nina', 'sand', 'fernglas', 'schwimmen', 'aktivist', 'auffangstation', 'piksen', 'reiterferien', 'sandmonster', 'waltraud', 'badehose', 'eisbecher', 'verfangen', 'handy', 'achsel', 'bock', 'shirt', 'blond', 'abkühlung', 'windig', 'streicheln', 'handtuch', 'runter']
# Story ID: 433 ['birke', 'bürgermeister', 'birkenbaum', 'motorsäge', 'sturmhaube', 'wahrscheinlich', 'sprühen', 'nolas', 'spraydose', 'waldmafia', 'bein', 'prächtig', 'auserwählen', 'ehefrau', 'vorsprung', 'vertrauen', 'jeep', 'kettensäge', 'pinken', 'schwere', 'polizei', 'gefühl', 'herunter', 'beifahrersitz', 'fesseln']
# Story ID: 436 ['riese', 'fußabdruck', 'coriese', 'coriesen', 'verbrennen', 'bus', 'benzin', 'gas', 'onkel', 'co', 'strom', 'albtraum', 'ausatmen', 'schrumpfen', 'ok', 'monster', 'cofußabdruck', 'cogas', 'küchenpflanzen', 'leuchtturm', 'syrien', 'welle', 'großmutter', 'wegspülen', 'blitz']
# Story ID: 438 ['großmutter', 'hexe', 'samen', 'hexenrat', 'hexenrates', 'wurzel', 'reise', 'reisen', 'kästchen', 'wurzelreisen', 'zauber', 'teil', 'lichtung', 'hügel', 'konzentrieren', 'gewächshaus', 'magie', 'sauern', 'raum', 'konzentrier', 'aufhalten', 'außen', 'zerstören', 'hattest', 'helfenich']
# Story ID: 439 ['regenwald', 'abgebrannt', 'australien', 'kängurus', 'handy', 'schämen', 'australisch', 'rad', 'wildnis', 'feld', 'papagei', 'verkohlen', 'internet', 'kümmern', 'koalas', 'abbrennen', 'gespannt', 'offenbaren', 'apfel', 'vorkommen', 'mitmachen', 'fahr', 'sprechend', 'gegenseitig', 'entgegen']
# Story ID: 440 ['wichtel', 'honig', 'waldbewohner', 'lichtung', 'großeltern', 'großvater', 'bach', 'geschwister', 'bienenunterkunft', 'wichteln', 'gebäude', 'funkgerät', 'ehe', 'material', 'hirsch', 'bau', 'wesen', 'brot', 'soweit', 'stall', 'faszinieren', 'fleißig', 'sodass', 'ungeduldig', 'kaninchen']
# Story ID: 442 ['kuckuck', 'eddi', 'nest', 'enterich', 'erpel', 'duft', 'ei', 'winterschlaf', 'verhexen', 'blumeninsel', 'hexenwald', 'wiesel', 'ruf', 'blinker', 'eichhörnchenschwanz', 'eiche', 'flasche', 'verzaubern', 'hexe', 'waschbär', 'frühling', 'feuersalamander', 'frühlingsanfang', 'winterfell', 'kalt']
# Story ID: 443 ['globus', 'deich', 'festland', 'boot', 'kontinent', 'amrum', 'husum', 'nordstrand', 'anziehungskraft', 'kommode', 'dachboden', 'hafen', 'weltuntergang', 'fisch', 'hölzern', 'fähre', 'segeln', 'schublade', 'strömung', 'erdanziehungskraft', 'est', 'kontinentaldrift', 'rassist', 'stelze', 'verschwörungstheoretiker']
# Story ID: 444 ['immergrünwald', 'troll', 'tanne', 'eimer', 'trockenheit', 'krieger', 'schwert', 'fichte', 'borkenkäfer', 'waldelfe', 'baumhaus', 'herrscher', 'strickleiter', 'zaubertrank', 'kobold', 'megafon', 'bart', 'gießenaber', 'lederstirnband', 'leonoras', 'spardose', 'torbens', 'eiche', 'buche', 'kämpfen']
# Story ID: 445 ['solar', 'ökostrom', 'ferienspaßkursen', 'umbauen', 'solarkollektor', 'betrieben', 'lkws', 'solarkurs', 'kosten', 'gucken', 'bräuchte', 'leiter', 'bahn', 'chemie', 'hausaufgaben', 'alleseinen', 'auot', 'autobaufabrik', 'autodach', 'chemiekurs', 'eslisa', 'ferienspaß', 'hmhmhm', 'pkws', 'suchenja']
# Story ID: 446 ['königin', 'lande', 'traktor', 'mähwerk', 'volk', 'blütenstaub', 'fliege', 'pumpen', 'nektar', 'freundin', 'halte', 'wild', 'blicke', 'taumeln', 'taschenlampe', 'magen', 'summe', 'flügel', 'bienenkönigin', 'gartenarbeiten', 'knalle', 'kämpferin', 'körper', 'erstmal', 'mai']
# Story ID: 448 ['hai', 'geld', 'therapie', 'hotel', 'fisch', 'wochenmarkt', 'boot', 'arzt', 'bücherei', 'hauptkörper', 'tourist', 'fischen', 'sammeln', 'symptom', 'gerät', 'bewusstsein', 'chemikalie', 'bewegen', 'dramatisch', 'krankenhaus', 'restaurant', 'verkaufen', 'netz', 'verdienen', 'betreuer']
# Story ID: 450 ['projektwoche', 'aula', 'schülerin', 'pinnwand', 'hausarbeit', 'glühbirne', 'dark', 'kilogramm', 'preisgeld', 'co', 'inzwischen', 'the', 'dunkelhaarigen', 'einsparen', 'parkplatz', 'knoten', 'beschreiben', 'veränderung', 'kommentieren', 'applaudieren', 'ergreifen', 'ernsthaft', 'ersetzen', 'gelächter', 'achtklässler']
# Story ID: 451 ['gespenst', 'kobold', 'robbe', 'greif', 'menschenkindern', 'rastplatz', 'zwergenkind', 'himalaya', 'waldgeister', 'reise', 'lehrerin', 'fabelwesen', 'troll', 'beschließen', 'gebirge', 'elfenkind', 'greife', 'greifs', 'yeti', 'berg', 'meermenschen', 'rucksack', 'halle', 'russland', 'rat']
# Story ID: 452 ['kröte', 'frosch', 'gruber', 'quaken', 'autofahrer', 'gartentür', 'cousin', 'planer', 'quaaak', 'tümpel', 'brille', 'co', 'demonstrieren', 'träne', 'fräulein', 'follower', 'unterhalb', 'video', 'zunge', 'flosse', 'couseng', 'gekränkt', 'gespalten', 'influencerin', 'laichen']
# Story ID: 463 ['tante', 'meier', 'schneemann', 'gas', 'schneemannwettbewerb', 'hexe', 'elsas', 'haferflockenkekse', 'leas', 'schneewettbewerb', 'trick', 'anführerin', 'kräutertee', 'kanne', 'feuer', 'strom', 'mohrrübe', 'preisverleihung', 'sitzkissen', 'winterferien', 'erfindung', 'winter', 'honig', 'onkel', 'kuh']
# Story ID: 464 ['wal', 'miller', 'surfen', 'zeugnis', 'möwe', 'flamme', 'großeltern', 'doktor', 'flüchten', 'schnabel', 'mittelschwer', 'sydney', 'kleinigkeit', 'fußball', 'spiel', 'dorf', 'sommerferien', 'feuer', 'maß', 'flugzeug', 'wahrscheinlich', 'riesige', 'brisbane', 'ethans', 'flugzeuges']
# Story ID: 469 ['pappbecher', 'einwegbecher', 'hasste', 'kakaobecher', 'ungleich', 'schreibtisch', 'vollkommen', 'kuscheldecke', 'mathematikunterricht', 'spiedermann', 'backstube', 'klassenzimmer', 'flauschige', 'erbse', 'klingel', 'anlaufen', 'augenbraue', 'unauffällig', 'rohstoff', 'bindfaden', 'buttercroissants', 'ladentheke', 'mathematikstunde', 'radiergummistückchen', 'spiderman']
# Story ID: 471 ['rektor', 'studierende', 'zollinger', 'polizei', 'café', 'festsaal', 'unternehmen', 'flugtickets', 'kellnerin', 'pyramide', 'reform', 'universität', 'tisch', 'geld', 'firma', 'türe', 'glas', 'dutzend', 'gewalt', 'verzicht', 'flugzeug', 'aktivistinnen', 'alkohol', 'ausgefallen', 'biographie']
# Story ID: 472 ['plane', 'tiger', 'schwimmend', 'dorf', 'henne', 'huhn', 'nani', 'sundarbans', 'fabrik', 'wahl', 'hütte', 'feld', 'fluss', 'arrangieren', 'banbibi', 'raft', 'rock', 'umziehen', 'motorboot', 'boot', 'großmutter', 'regen', 'zwingen', 'reis', 'scharren']
# Story ID: 473 ['finn', 'wilder', 'innen', 'bienenhotels', 'schüler', 'abfrage', 'kamal', 'portrait', 'redaktionsteam', 'schwänzeltanz', 'gestaltung', 'wilde', 'schulgebäude', 'aysegül', 'bienenhotel', 'hoffmann', 'nabu', 'sicherlich', 'bestäubung', 'werben', 'dennoch', 'smartphone', 'pestizid', 'nutzen', 'nahrung']
# Story ID: 474 ['wolf', 'hirsch', 'strasse', 'regierung', 'kohle', 'mittelhofen', 'meldung', 'verstopfen', 'krähen', 'schatten', 'selber', 'bär', 'industrie', 'autohändler', 'emmisie', 'militär', 'öl', 'helikoptern', 'zuhören', 'aufja', 'kamera', 'russland', 'soldat', 'plakat', 'grube']
# Story ID: 475 ['teich', 'schlauch', 'pumpe', 'jungs', 'dachrinne', 'leitung', 'rohr', 'regnen', 'steg', 'wanne', 'eiscafe', 'brunnen', 'siedlung', 'blitz', 'rad', 'städtchen', 'erkundigen', 'auffüllen', 'arschbombe', 'bachbett', 'luftmatratze', 'stubenhocker', 'wasserleitung', 'austrocknen', 'baden']
# Story ID: 478 ['trauerweide', 'schulleiterin', 'autoreifen', 'ast', 'tannenzapfen', 'weide', 'verwandeln', 'zweig', 'schokokeks', 'biologielehrerin', 'sonnenbrillen', 'baumhöhle', 'sonnenbrille', 'spaghetti', 'verfärben', 'eingangstor', 'grundwasser', 'dienstag', 'intensiv', 'holzstühle', 'marsfrau', 'organikalisiert', 'seltsam', 'buche', 'dunkel']
# Story ID: 479 ['jorin', 'lehmbach', 'tagebau', 'bach', 'jorins', 'braunkohle', 'bürgermeister', 'bandenquartier', 'bachlauf', 'kröte', 'boot', 'zwilling', 'erwachsene', 'segel', 'solaranlage', 'bachbiegung', 'braunkohleabbau', 'leitungsteam', 'ziellinie', 'arbeitsplätze', 'fließen', 'unterstützung', 'region', 'alternative', 'bachlaufs']
# Story ID: 480 ['nawitag', 'weltretter', 'nähen', 'stuhlkreis', 'schuljahr', 'aula', 'malen', 'naturwissenschaften', 'bunt', 'informieren', 'besprechen', 'anmeldeliste', 'lieblingsfach', 'matheclub', 'nähmaschine', 'wasserfarbkasten', 'jacke', 'langweilen', 'stofftaschen', 'zeichenblock', 'stift', 'nahrung', 'raum', 'reißverschluss', 'unterschiedlich']
# Story ID: 485 ['schnepfe', 'temko', 'strandabschnitt', 'tanja', 'seehundexpertin', 'absperrung', 'düne', 'seehunde', 'seehunden', 'seehund', 'seehundbaby', 'klimakrise', 'reporterin', 'schaulustige', 'kläffen', 'polizistin', 'öko', 'tasse', 'tourist', 'box', 'möwe', 'bananenspliteis', 'bohlenweg', 'filterkaffee', 'hochhackigen']
# Story ID: 486 ['raucher', 'höhle', 'bunker', 'schwarze', 'erwachsene', 'aufgabe', 'ausbessern', 'glinda', 'versammlungsplatz', 'gruppe', 'jeweilig', 'kartoffel', 'gemeinschaft', 'versammlung', 'arbeitsgruppen', 'ashbel', 'finnegan', 'gemeinschaftsküche', 'haupthöhle', 'jauchegrube', 'kriegsgesang', 'spähergruppe', 'tierpatenschaften', 'unterstützt', 'william']
# Story ID: 487 ['scholle', 'seehunde', 'eisdecke', 'packeis', 'atmung', 'wasseroberfläche', 'eisscholle', 'eispaddel', 'eisstücken', 'motorschlitten', 'seehundjungen', 'waisenhaus', 'meter', 'weißt', 'polarmeer', 'seehund', 'seehündin', 'worten', 'haube', 'schwimmen', 'kälte', 'entfernen', 'okay', 'stoff', 'nudel']
# Story ID: 488 ['papagei', 'regenwald', 'mülltonnen', 'banane', 'verband', 'feuer', 'dorfarzt', 'mantos', 'phillip', 'schmerz', 'versuche', 'blutspur', 'hartplastik', 'müllgabel', 'krächzen', 'entgegnen', 'abendessen', 'sensibel', 'papier', 'dorf', 'fiepen', 'kampagne', 'salbe', 'hütte', 'schaukel']
# Story ID: 489 ['patsche', 'maus', 'moor', 'pappili', 'plastikteller', 'flitzer', 'rinnsal', 'stöckchen', 'pfote', 'berts', 'mäusekinderschar', 'bericht', 'hell', 'trocken', 'gefährt', 'warme', 'teller', 'habicht', 'halbstarken', 'hugo', 'moospolster', 'mäusegefährt', 'schlammspuren', 'selbstbewußt', 'stromschnellen']
# Story ID: 490 ['wolkenland', 'tröpfchen', 'jüngling', 'umwelten', 'bürger', 'junior', 'skys', 'lehrer', 'pinzette', 'wolkenländer', 'gewebe', 'regen', 'handbuch', 'wolkenbürger', 'funktion', 'körper', 'plattform', 'gelten', 'anmessen', 'einwandfreie', 'skyes', 'verweigern', 'regierung', 'weiterhin', 'nebel']
# Story ID: 491 ['erinnerung', 'empfänger', 'training', 'gemeinschaft', 'zeremonie', 'älteste', 'kindheitnummer', 'dank', 'regel', 'schlitten', 'geber', 'position', 'dreieck', 'geburtsmütter', 'kindheit', 'baby', 'schmerz', 'entschuldigen', 'vergangenheit', 'hallo', 'grenze', 'entschuldigung', 'gesellschaft', 'willkommen', 'tablett']
# Story ID: 492 ['altvorderen', 'zone', 'kultur', 'pirat', 'ruine', 'boot', 'london', 'bibliothek', 'permanent', 'elektropiraten', 'regel', 'schwimmend', 'grahams', 'house', 'metzgerei', 'höflich', 'unterholz', 'permakultur', 'markt', 'tauchen', 'gemeinschaft', 'anlass', 'geleise', 'library', 'senate']
# Story ID: 494 ['geschwister', 'eule', 'blatt', 'maschine', 'böse', 'fee', 'zulassen', 'müllhausen', 'teich', 'absicht', 'gebäude', 'waldlichtung', 'geschehen', 'mut', 'sanft', 'monster', 'wolle', 'blaubeere', 'lauras', 'verwuschelte', 'ha', 'lichtung', 'lied', 'schwesterherz', 'namens']
#      story_id                                           keywords
# 0          19  [wolke, bulk, zukunftsmusik, spiegel, kohlendi...
# 1          21  [dorf, bürgermeister, schneien, wettbewerb, pf...
# 2          24  [frosch, stiefmutter, wolf, prinz, hexe, feige...
# 3          25  [geist, schlafzimmer, lebensstil, wesen, himbe...
# 4          27  [vampir, ratte, viola, beere, stall, see, burg...
# ..        ...                                                ...
# 195       489  [patsche, maus, moor, pappili, plastikteller, ...
# 196       490  [wolkenland, tröpfchen, jüngling, umwelten, bü...
# 197       491  [erinnerung, empfänger, training, gemeinschaft...
# 198       492  [altvorderen, zone, kultur, pirat, ruine, boot...
# 199       494  [geschwister, eule, blatt, maschine, böse, fee...
#
# [200 rows x 2 columns]

# %% [markdown]
# <p class="h4 alert alert-danger">
#     Please make sure to install package wordcloud in the virtual environment
#     pip install wordcloud
# </p>

# %%
"""
Word Cloud generator
"""

from wordcloud import WordCloud, STOPWORDS
import re
from os import path
import string
from PIL import Image
import matplotlib.pyplot as plt

#change the index number here to make different wordclouds
index=2
# d = path.dirname(__file__)
alice_mask = np.array(Image.open("tree.png"))


wordcloud = WordCloud(
    background_color='white',
    max_words=200,
    max_font_size=120, 
    width=1000, height=800,
    random_state=42,
    mask=alice_mask
).generate(corpus[index]) #change the index number here to make different wordclouds

print(wordcloud)
fig = plt.figure(figsize = (8,10))
plt.imshow(wordcloud)
plt.title("WORD CLOUD - Story impression",fontsize=15)
plt.axis('off')

plt.show()
filename='WordCloudID'+df['story_id'][index].astype('str')+'.jpg'
wordcloud.to_file(filename)
# Out:
# <wordcloud.wordcloud.WordCloud object at 0x1227d6550>

# %%
"""
BERT Embedding
"""
# create bert client
client = bert.BertClient(check_length=False)

# encode token-lemmas from our data into bert-vectors
vectors = client.encode(df['lemmas'].values.tolist(), show_tokens=False, is_tokenized=True)

print(len(vectors))
# Out:
# 200

# %%
"""
Word_Cloud for categories:
"""
